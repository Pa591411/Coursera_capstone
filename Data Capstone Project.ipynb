# %% [markdown]
# # Data Project

# %% [markdown]
# ### Using University data to predict carbon emmissions outputs, based on staff numbers and students, to predict appropriate carbon emmissions targets. We will then also review, if regional factors affect carbon emmissions.

# %% [markdown]
# ## Section 1: Preparing the data

# %% [markdown]
# #### First, we need to import our libraries, and wrangle the data into a format that is appropriate for our aims.

# %%
#importing required libraries

import pandas as pd
from pandas.io.json import json_normalize
import sklearn as sk
from sklearn.cluster import KMeans
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import json
import requests
import geopy
from geopy.geocoders import Nominatim
import folium

# %%
#Loading data
student_data = pd.read_csv('student_data.csv')
staff_data = pd.read_csv('staff_data.csv')
emr_data = pd.read_csv('emr_data.csv')
location_data = pd.read_csv('provider data.csv')
# Out:
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# We only want to use data from the academic year 2018/19, and we only want to estimate scope 1 and 2 carbon emissions (which are those caused directly by University operations), so we need to filter out the other data.

# %%
#Filtering the data sets
stu_filtered = student_data['Academic year']=='2018/19'
df1 = pd.DataFrame(student_data[stu_filtered])

sta_filtered = staff_data['Academic Year']=='2018/19'
df2 = pd.DataFrame(staff_data[sta_filtered])

EMR1_filtered = emr_data['Academic Year']=='2018/19'
EMR2_filtered = emr_data[EMR1_filtered]
EMR3_filtered = EMR2_filtered['Category']=='Total gross internal area (m2)'
df3 = pd.DataFrame(EMR2_filtered[EMR3_filtered])

EMR4_filtered = emr_data['Academic Year']=='2018/19'
EMR5_filtered = emr_data[EMR4_filtered]
EMR6_filtered = EMR5_filtered['Category']=='Total scope 1 and 2 carbon emissions (Kg CO2e)'
df4 = pd.DataFrame(EMR5_filtered[EMR6_filtered])

# %% [markdown]
# We want our final data to show student number, staff number, GIA, and carbon emmissions per institution, so we need to group by UKPRN (the unique provider number) and then merge the data.

# %%
#grouping the data by provider
df1 = df1.groupby(by='UKPRN').sum()
df2 = df2.groupby(by='UKPRN').sum()
df3 = df3.groupby(by='UKPRN').sum()
df4 = df4.groupby(by='UKPRN').sum()

# %%
#merging the data into one dataframe
c_df = pd.merge(df1, df2, on ="UKPRN")
c_df2 = pd.merge(df3, df4, on ="UKPRN")

data1 = pd.merge(c_df, c_df2, on ="UKPRN")
data = pd.merge(data1, location_data, on ="UKPRN")

# %%
#cleaning the dataframe and renaming columns
data = data[['UKPRN', 'HE Provider_x', 'Number_x', 'Number_y', 'Value_x', 'Value_y', 'LONGITUDE', 'LATITUDE']]
s_data = data.rename(columns={'HE Provider_x':'Provider', 'Number_x':'Student_Number', 'Number_y':'Staff_Number', 'Value_x':'GIA', 'Value_y':'Carbon_Emissions_Kg_CO2e', 'LATITUDE':'Latitude', 'LONGITUDE':'Longitude'})
c_data = s_data.dropna()

# %% [markdown]
# Here is our data:

# %%
c_data[["GIA", "Carbon_Emissions_Kg_CO2e"]] = c_data[["GIA", "Carbon_Emissions_Kg_CO2e"]].apply(pd.to_numeric)
c_data
# Out:
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#           UKPRN                           Provider  Student_Number  \
# 0    10000291.0           Anglia Ruskin University         1763180
# 1    10000385.0    The Arts University Bournemouth          243940
# 2    10000571.0                Bath Spa University          559280
# 3    10000712.0      University College Birmingham          353240
# 4    10000824.0             Bournemouth University         1287320
# ..          ...                                ...             ...
# 150  10008026.0       St Mary's University College           75260
# 151  10008640.0                Falmouth University          462420
# 152  10014001.0              University of Suffolk          553860
# 153  10037449.0  University of St Mark and St John          199600
# 154  10040812.0            Harper Adams University          387040
#
#      Staff_Number        GIA  Carbon_Emissions_Kg_CO2e  Longitude   Latitude
# 0          118000  129750.17               6005516.418   0.474311  51.741266
# 1           22720   35090.95               1133069.664  -1.897700  50.741781
# 2           51160   68954.00               2486984.472  -2.437400  51.378739
# 3           27060   67293.81               3102714.214  -1.905934  52.481855
# 4           75420   91393.00               3581959.766  -1.897159  50.742968
# ..            ...        ...                       ...        ...        ...
# 150          6240   14585.00                490116.680  -5.961300  54.592000
# 151         24120   74766.92               2993218.522  -5.070901  50.149168
# 152         22200   27071.30               1164296.062   1.162554  52.052585
# 153         16600   34443.00               1689156.066  -4.110286  50.421023
# 154         23660   57624.89               2499883.587  -2.425380  52.780019
#
# [154 rows x 8 columns]

# %% [markdown]
# We'll add a couple more columns for further testing:

# %%
c_data['GIA_per_student'] = c_data['GIA']/(c_data['Student_Number'])
c_data['GIA_per_staff'] = c_data['GIA']/(c_data['Staff_Number'])
c_data
# Out:
# <ipython-input-8-1715a3f07801>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_data['GIA_per_student'] = c_data['GIA']/(c_data['Student_Number'])
# <ipython-input-8-1715a3f07801>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_data['GIA_per_staff'] = c_data['GIA']/(c_data['Staff_Number'])
#           UKPRN                           Provider  Student_Number  \
# 0    10000291.0           Anglia Ruskin University         1763180
# 1    10000385.0    The Arts University Bournemouth          243940
# 2    10000571.0                Bath Spa University          559280
# 3    10000712.0      University College Birmingham          353240
# 4    10000824.0             Bournemouth University         1287320
# ..          ...                                ...             ...
# 150  10008026.0       St Mary's University College           75260
# 151  10008640.0                Falmouth University          462420
# 152  10014001.0              University of Suffolk          553860
# 153  10037449.0  University of St Mark and St John          199600
# 154  10040812.0            Harper Adams University          387040
#
#      Staff_Number        GIA  Carbon_Emissions_Kg_CO2e  Longitude   Latitude  \
# 0          118000  129750.17               6005516.418   0.474311  51.741266
# 1           22720   35090.95               1133069.664  -1.897700  50.741781
# 2           51160   68954.00               2486984.472  -2.437400  51.378739
# 3           27060   67293.81               3102714.214  -1.905934  52.481855
# 4           75420   91393.00               3581959.766  -1.897159  50.742968
# ..            ...        ...                       ...        ...        ...
# 150          6240   14585.00                490116.680  -5.961300  54.592000
# 151         24120   74766.92               2993218.522  -5.070901  50.149168
# 152         22200   27071.30               1164296.062   1.162554  52.052585
# 153         16600   34443.00               1689156.066  -4.110286  50.421023
# 154         23660   57624.89               2499883.587  -2.425380  52.780019
#
#      GIA_per_student  GIA_per_staff
# 0           0.073589       1.099578
# 1           0.143851       1.544496
# 2           0.123291       1.347811
# 3           0.190505       2.486837
# 4           0.070995       1.211787
# ..               ...            ...
# 150         0.193795       2.337340
# 151         0.161686       3.099789
# 152         0.048878       1.219428
# 153         0.172560       2.074880
# 154         0.148886       2.435541
#
# [154 rows x 10 columns]

# %% [markdown]
# Now that we have the data, we'll plot all the UK universities on a map

# %%
address = 'UK'

geolocator = Nominatim(user_agent="UK")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude


print(latitude, longitude)
# Out:
# 54.7023545 -3.2765753

# %%
#mapping UK

map_UK = folium.Map(location=[latitude, longitude], zoom_start=5)

for latitude, longitude, Provider in zip(c_data['Latitude'], c_data['Longitude'], c_data['Provider']):
    label = '{}'.format(Provider)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [latitude, longitude],
        radius=2,
        popup=label,
        color='black',
        fill=False
        ).add_to(map_UK)  
    
map_UK
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Section 2: Testing the correlation between carbon emmissions, staff and student populations, and gross internal area

# %% [markdown]
# #### Next we will test some key relationships, to assess how to best predict carbon emmisions based off available data. These will be the relationships between:
#    - Student populations and carbon emmissions
#    - Staff populations and carbon emmissions
#    - Gross internal area and carbon emmisions
#    - Carbon emmisions and gross internal area per student
#    - Carbon emmisions and gross internal area per staff
#
# We will first model these separately, and then conduct multiple linear regression, to the strength of the correlations.
# The tests will follow the structure:
# 1. plotting the variables on a scatter graph
# 2. Analysing the linear regression, to get the coefficient and intercept
# 3. plotting the linear regression on top of the scatter chart
# 4. analysing the strength of the linear regression

# %%
#Split into train and test
msk = np.random.rand(len(c_data)) < 0.8
train = c_data[msk]
test = c_data[~msk]

# %% [markdown]
# ##### test 1

# %%
#Train Data distribution
plt.scatter(train.Student_Number, train.Carbon_Emissions_Kg_CO2e, color='Grey')
plt.xlabel("Student_Number")
plt.ylabel("Carbon_Emissions_Kg_CO2e")
plt.show()

# %%
#Modelling Data
regr1 = linear_model.LinearRegression()
train_x1 = np.asanyarray(train[['Student_Number']])
train_y1 = np.asanyarray(train[["Carbon_Emissions_Kg_CO2e"]])
regr1.fit (train_x1, train_y1)
print ('Coefficients: ', regr1.coef_)
print ('Intercept: ',regr1.intercept_)
# Out:
# Coefficients:  [[6.20482661]]
# Intercept:  [4302319.41509638]

# %%
#Plot Outputs
plt.scatter(train.Student_Number, train.Carbon_Emissions_Kg_CO2e, color='Grey')
plt.plot(train_x1, regr1.coef_[0][0]*train_x1 + regr1.intercept_[0], '-r')
plt.xlabel('Student_Number')
plt.ylabel("Carbon_Emissions_Kg_CO2e")
# Out:
# Text(0, 0.5, 'Carbon_Emissions_Kg_CO2e')

# %%
#Evaluation
test_x1 = np.asanyarray(test[['Student_Number']])
test_y1 = np.asanyarray(test[["Carbon_Emissions_Kg_CO2e"]])
test_y_1 = regr1.predict(test_x1)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_1 - test_y1)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_1 - test_y1) ** 2))
print("R2-score: %.2f" % r2_score(test_y1 , test_y_1) )
# Out:
# Mean absolute error: 5538932.50
# Residual sum of squares (MSE): 43538825735785.99
# R2-score: 0.43

# %% [markdown]
# We can see that there is no strong correlation between student number and carbon emmissions, though from the graph, this may be because of the outlier in the bottom right. If we were only relying on this variable, we would filter out the outlier to create a more reliable metric.

# %% [markdown]
# #### test 2

# %%
#Train Data distribution
plt.scatter(train.Staff_Number, train.Carbon_Emissions_Kg_CO2e, color='blue')
plt.xlabel("Staff_Number")
plt.ylabel("Carbon_Emissions_Kg_CO2e")
plt.show()

# %%
#Modelling Data
regr2 = linear_model.LinearRegression()
train_x2 = np.asanyarray(train[['Staff_Number']])
train_y2 = np.asanyarray(train[["Carbon_Emissions_Kg_CO2e"]])
regr2.fit (train_x2, train_y2)
print ('Coefficients: ', regr2.coef_)
print ('Intercept: ',regr2.intercept_)
# Out:
# Coefficients:  [[95.08300104]]
# Intercept:  [-941097.88254615]

# %%
#Plot Outputs
plt.scatter(train.Staff_Number, train.Carbon_Emissions_Kg_CO2e, color='blue')
plt.plot(train_x2, regr2.coef_[0][0]*train_x2 + regr2.intercept_[0], '-r')
plt.xlabel("Staff_Number")
plt.ylabel("Carbon_Emissions_Kg_CO2e")
# Out:
# Text(0, 0.5, 'Carbon_Emissions_Kg_CO2e')

# %%
#Evaluation
test_x2 = np.asanyarray(test[['Staff_Number']])
test_y2 = np.asanyarray(test[["Carbon_Emissions_Kg_CO2e"]])
test_y_2 = regr2.predict(test_x2)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_2 - test_y2)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_2 - test_y2) ** 2))
print("R2-score: %.2f" % r2_score(test_y2 , test_y_2) )
# Out:
# Mean absolute error: 2206371.42
# Residual sum of squares (MSE): 8770021945568.03
# R2-score: 0.89

# %% [markdown]
# This test creates a much stronger correlation, showing that as staff numbers increase, so will carbon emmissions. The high R2-score indicates that we can be fairly confident in this metric.

# %% [markdown]
# #### test 3

# %%
#Train Data distribution
plt.scatter(train.GIA, train.Carbon_Emissions_Kg_CO2e, color='Green')
plt.xlabel("GIA")
plt.ylabel("Carbon_Emissions_Kg_CO2e")
plt.show()

# %%
#Modelling Data
regr3 = linear_model.LinearRegression()
train_x3 = np.asanyarray(train[['GIA']])
train_y3 = np.asanyarray(train[["Carbon_Emissions_Kg_CO2e"]])
regr3.fit (train_x3, train_y3)
print ('Coefficients: ', regr3.coef_)
print ('Intercept: ',regr3.intercept_)
# Out:
# Coefficients:  [[69.77836371]]
# Intercept:  [-2839920.37441851]

# %%
#Plot Outputs
plt.scatter(train.GIA, train.Carbon_Emissions_Kg_CO2e, color='Green')
plt.plot(train_x3, regr3.coef_[0][0]*train_x3 + regr3.intercept_[0], '-r')
plt.xlabel("GIA")
plt.ylabel("Carbon_Emissions_Kg_CO2e")
# Out:
# Text(0, 0.5, 'Carbon_Emissions_Kg_CO2e')

# %%
#Evaluation
test_x3 = np.asanyarray(test[['GIA']])
test_y3 = np.asanyarray(test[["Carbon_Emissions_Kg_CO2e"]])
test_y_3 = regr3.predict(test_x3)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_3 - test_y3)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_3 - test_y3) ** 2))
print("R2-score: %.2f" % r2_score(test_y3 , test_y_3) )
# Out:
# Mean absolute error: 1846769.42
# Residual sum of squares (MSE): 5360792788276.58
# R2-score: 0.93

# %% [markdown]
# Again, this creates a strong correlation between GIA and carbon emissions, with a similar R2 score.

# %% [markdown]
# #### test 4

# %%
#Train Data distribution
plt.scatter(train.GIA_per_student, train.Carbon_Emissions_Kg_CO2e, color='purple')
plt.xlabel("GIA_per_student")
plt.ylabel("Carbon_Emissions_Kg_CO2e")
plt.show()

# %%
#Modelling Data
regr4 = linear_model.LinearRegression()
train_x4 = np.asanyarray(train[["GIA_per_student"]])
train_y4 = np.asanyarray(train[["Carbon_Emissions_Kg_CO2e"]])
regr4.fit (train_x4, train_y4)
print ('Coefficients: ', regr4.coef_)
print ('Intercept: ',regr4.intercept_)
# Out:
# Coefficients:  [[19528743.3847379]]
# Intercept:  [7365804.32014811]

# %%
#Plot Outputs
plt.scatter(train.GIA_per_student, train.Carbon_Emissions_Kg_CO2e, color='purple')
plt.plot(train_x4, regr4.coef_[0][0]*train_x4 + regr4.intercept_[0], '-r')
plt.xlabel("GIA_per_student")
plt.ylabel("Carbon_Emissions_Kg_CO2e")
# Out:
# Text(0, 0.5, 'Carbon_Emissions_Kg_CO2e')

# %% [markdown]
# This does not give us a clear correlation, so we don't need to evaluate the strength of the relationship.

# %% [markdown]
# #### test 5

# %%
#Train Data distribution
plt.scatter(train.GIA_per_staff, train.Carbon_Emissions_Kg_CO2e, color='pink')
plt.xlabel("GIA_per_staff")
plt.ylabel("Carbon_Emissions_Kg_CO2e")
plt.show()

# %%
#Modelling Data
regr5 = linear_model.LinearRegression()
train_x5 = np.asanyarray(train[['GIA_per_staff']])
train_y5 = np.asanyarray(train[["Carbon_Emissions_Kg_CO2e"]])
regr5.fit (train_x5, train_y5)
print ('Coefficients: ', regr5.coef_)
print ('Intercept: ',regr5.intercept_)
# Out:
# Coefficients:  [[-635323.57695001]]
# Intercept:  [12600383.06084633]

# %%
#Plot Outputs
plt.scatter(train.GIA_per_staff, train.Carbon_Emissions_Kg_CO2e, color='pink')
plt.plot(train_x5, regr5.coef_[0][0]*train_x5 + regr5.intercept_[0], '-r')
plt.xlabel("GIA_per_staff")
plt.ylabel("Carbon_Emissions_Kg_CO2e")
# Out:
# Text(0, 0.5, 'Carbon_Emissions_Kg_CO2e')

# %% [markdown]
# likewise, as there is no clear correlation, we will not evaluate the relationship

# %% [markdown]
# #### Multiple Linear Regression

# %% [markdown]
# based off our initial testing, we can see that the strongest variables are student number, staff number, and GIA, so we will factor these into a multiple linear regression test, to build a more informed model.

# %%
regrml = linear_model.LinearRegression()
x_ml = np.asanyarray(train[['Student_Number','Staff_Number','GIA']])
y_ml = np.asanyarray(train[["Carbon_Emissions_Kg_CO2e"]])
regrml.fit (x_ml, y_ml)
# The coefficients
print ('Coefficients: ', regrml.coef_)
# Out:
# Coefficients:  [[-2.12241676 46.6113806  45.93108333]]

# %%
y_hat_ml = regrml.predict(test[['Student_Number','Staff_Number','GIA']])
x_ml = np.asanyarray(test[['Student_Number','Staff_Number','GIA']])
y_ml = np.asanyarray(test[["Carbon_Emissions_Kg_CO2e"]])
print("Residual sum of squares: %.2f"
      % np.mean((y_hat_ml - y_ml) ** 2))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regrml.score(x_ml, y_ml))
# Out:
# Residual sum of squares: 3566357776012.19
# Variance score: 0.95

# %% [markdown]
# from the vaiance score, we can see that the model will create a prediction with a high degree of accuracy.

# %% [markdown]
# ## Section 3: Clustering the data, to create benchmark groups

# %% [markdown]
# #### Now that we have information on relationships between our variables, we will separate our data into clusters, to create benchmark groups for University carbon emmissions targerts

# %%
c_data_clustering = c_data.drop('Provider', 1)

# %%
X_cluster = c_data_clustering.values[:,1:]
X_cluster = np.nan_to_num(X_cluster)
cluster_dataset = StandardScaler().fit_transform(X_cluster)
cluster_dataset
# Out:
# array([[ 0.71454011, -0.02051444, -0.3508018 , ..., -0.59115822,
#         -0.24473361, -0.65403616],
#        [-0.89000277, -0.81356662, -0.89808621, ..., -1.19345158,
#         -0.15920217, -0.25310288],
#        [-0.55695694, -0.57684953, -0.70230265, ..., -0.80961833,
#         -0.1842304 , -0.43034364],
#        ...,
#        [-0.56268126, -0.81789478, -0.94445285, ..., -0.40355624,
#         -0.2748151 , -0.54603445],
#        [-0.93683239, -0.86450574, -0.90183242, ..., -1.38674154,
#         -0.12425364,  0.22484638],
#        [-0.73886794, -0.80574264, -0.76780335, ...,  0.03479819,
#         -0.15307248,  0.54985215]])

# %%
num_clusters = 10

k_means = KMeans(init="k-means++", n_clusters=num_clusters, n_init=12)
k_means.fit(cluster_dataset)
labels = k_means.labels_

print(labels)
# Out:
# [8 5 1 1 8 8 8 5 8 2 8 5 2 2 9 5 7 5 5 0 8 1 2 1 1 1 2 5 8 8 2 2 8 5 2 8 9
#  9 5 9 5 1 8 9 2 1 1 5 5 1 0 4 5 1 2 2 2 8 1 8 8 2 8 8 8 8 0 8 2 0 0 2 8 2
#  8 0 2 8 2 4 5 1 1 5 5 9 9 1 2 5 5 9 6 7 8 8 5 5 5 5 5 9 7 1 0 7 8 7 8 2 2
#  0 0 2 3 7 0 9 2 8 9 9 9 8 9 5 0 5 8 1 5 1 1 5 1 9 5 2 9 2 2 9 1 2 1 1 1 9
#  5 9 1 5 1 1]

# %%
c_data["Labels"] = pd.Categorical(labels)
c_data.head(5)
# Out:
# <ipython-input-35-306cc1d4bb4e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c_data["Labels"] = pd.Categorical(labels)
#         UKPRN                         Provider  Student_Number  Staff_Number  \
# 0  10000291.0         Anglia Ruskin University         1763180        118000
# 1  10000385.0  The Arts University Bournemouth          243940         22720
# 2  10000571.0              Bath Spa University          559280         51160
# 3  10000712.0    University College Birmingham          353240         27060
# 4  10000824.0           Bournemouth University         1287320         75420
#
#          GIA  Carbon_Emissions_Kg_CO2e  Longitude   Latitude  GIA_per_student  \
# 0  129750.17               6005516.418   0.474311  51.741266         0.073589
# 1   35090.95               1133069.664  -1.897700  50.741781         0.143851
# 2   68954.00               2486984.472  -2.437400  51.378739         0.123291
# 3   67293.81               3102714.214  -1.905934  52.481855         0.190505
# 4   91393.00               3581959.766  -1.897159  50.742968         0.070995
#
#    GIA_per_staff Labels
# 0       1.099578      8
# 1       1.544496      5
# 2       1.347811      1
# 3       2.486837      1
# 4       1.211787      8

# %%
we need the mean carbon emission from each group for our results later

# %%
mean = c_data.groupby(['Labels']).mean()
mean
# Out:
#                UKPRN  Student_Number   Staff_Number            GIA  \
# Labels
# 0       1.000710e+07    2.150355e+06  323849.090909  517670.529182
# 1       1.000876e+07    5.199800e+05   47729.629630   93403.417926
# 2       1.000616e+07    1.622390e+06  145500.740741  227589.298370
# 3       1.000780e+07    1.760000e+04   43100.000000  179130.000000
# 4       1.000714e+07    1.043860e+06   31880.000000  280345.955000
# 5       1.000638e+07    2.975987e+05   35010.666667   42132.675000
# 6       1.000777e+07    8.809775e+06  355440.000000  131297.000000
# 7       1.000703e+07    2.173200e+06  531853.333333  722043.354833
# 8       1.000552e+07    1.236986e+06  116660.666667  182825.248633
# 9       1.000707e+07    8.342558e+05   82549.473684  158537.932316
#
#         Carbon_Emissions_Kg_CO2e  Longitude   Latitude  GIA_per_student  \
# Labels
# 0                   3.274407e+07  -1.996826  52.923892         0.243801
# 1                   3.533777e+06  -2.600155  52.580844         0.191151
# 2                   1.090848e+07  -2.148262  52.962709         0.148805
# 3                   7.234093e+06  -0.127819  51.520998        10.177841
# 4                   1.277720e+07  -2.642174  55.709056         0.252736
# 5                   2.103158e+06  -0.198053  51.557295         0.265189
# 6                   7.127026e+06  -0.709726  52.024924         0.014904
# 7                   5.481265e+07  -1.146526  52.734031         0.352838
# 8                   9.027025e+06  -0.190645  51.623322         0.162128
# 9                   9.160559e+06  -3.915080  55.821289         0.252520
#
#         GIA_per_staff
# Labels
# 0            1.605391
# 1            2.089067
# 2            1.594009
# 3            4.156148
# 4            9.491069
# 5            1.394671
# 6            0.369393
# 7            1.389405
# 8            1.635380
# 9            2.171494

# %% [markdown]
# Now that we have the clusters, we'll visualise these on our map to see how well they are spread out.

# %% [raw]
# viz = mean[['Student_Number','Staff_Number','GIA','Carbon_Emissions_Kg_CO2e']]
# viz.hist()
# plt.show()

# %%
cluster_map = folium.Map(location=[latitude, longitude], zoom_start=5)

# set color scheme for the clusters
x_clusters = np.arange(num_clusters)
ys = [i+x_clusters+(i*x_clusters)**2 for i in range(num_clusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(c_data['Latitude'], c_data['Longitude'], c_data['Provider'],k_means.labels_):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=2,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(cluster_map)
cluster_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Section 4: Mapping the results, to analyse any regional disparity

# %% [markdown]
# #### Now that we have information on the relationships between our variables, and benchmark clusters, we will map these to assess if there are any visual regional changes in carbon emmissions, or any of our independent variables.

# %%
c_data
# Out:
#           UKPRN                           Provider  Student_Number  \
# 0    10000291.0           Anglia Ruskin University         1763180
# 1    10000385.0    The Arts University Bournemouth          243940
# 2    10000571.0                Bath Spa University          559280
# 3    10000712.0      University College Birmingham          353240
# 4    10000824.0             Bournemouth University         1287320
# ..          ...                                ...             ...
# 150  10008026.0       St Mary's University College           75260
# 151  10008640.0                Falmouth University          462420
# 152  10014001.0              University of Suffolk          553860
# 153  10037449.0  University of St Mark and St John          199600
# 154  10040812.0            Harper Adams University          387040
#
#      Staff_Number        GIA  Carbon_Emissions_Kg_CO2e  Longitude   Latitude  \
# 0          118000  129750.17               6005516.418   0.474311  51.741266
# 1           22720   35090.95               1133069.664  -1.897700  50.741781
# 2           51160   68954.00               2486984.472  -2.437400  51.378739
# 3           27060   67293.81               3102714.214  -1.905934  52.481855
# 4           75420   91393.00               3581959.766  -1.897159  50.742968
# ..            ...        ...                       ...        ...        ...
# 150          6240   14585.00                490116.680  -5.961300  54.592000
# 151         24120   74766.92               2993218.522  -5.070901  50.149168
# 152         22200   27071.30               1164296.062   1.162554  52.052585
# 153         16600   34443.00               1689156.066  -4.110286  50.421023
# 154         23660   57624.89               2499883.587  -2.425380  52.780019
#
#      GIA_per_student  GIA_per_staff Labels
# 0           0.073589       1.099578      8
# 1           0.143851       1.544496      5
# 2           0.123291       1.347811      1
# 3           0.190505       2.486837      1
# 4           0.070995       1.211787      8
# ..               ...            ...    ...
# 150         0.193795       2.337340      9
# 151         0.161686       3.099789      1
# 152         0.048878       1.219428      5
# 153         0.172560       2.074880      1
# 154         0.148886       2.435541      1
#
# [154 rows x 11 columns]

# %%
m = folium.Map(location=[latitude, longitude], zoom_start=5)

for i in range(0,len(c_data)):
   folium.Circle(
      location=[c_data.iloc[i]['Latitude'], c_data.iloc[i]['Longitude']],
      popup=c_data.iloc[i]['Provider'],
      radius=c_data.iloc[i]['Carbon_Emissions_Kg_CO2e']/1250,
      color='Orange',
      fill=True,
      fill_color='orange'
   ).add_to(m)
 
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m2 = folium.Map(location=[latitude, longitude], zoom_start=5)

for i in range(0,len(c_data)):
   folium.Circle(
      location=[c_data.iloc[i]['Latitude'], c_data.iloc[i]['Longitude']],
      popup=c_data.iloc[i]['Provider'],
      radius=c_data.iloc[i]['GIA']/19,
      color='Green',
      fill=True,
      fill_color='Green'
   ).add_to(m2)
 
    
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m3 = folium.Map(location=[latitude, longitude], zoom_start=5)

for i in range(0,len(c_data)):
   folium.Circle(
      location=[c_data.iloc[i]['Latitude'], c_data.iloc[i]['Longitude']],
      popup=c_data.iloc[i]['Provider'],
      radius=c_data.iloc[i]['Student_Number']/100,
      color='Grey',
      fill=True,
      fill_color='Grey'
   ).add_to(m3)
 
    
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m4 = folium.Map(location=[latitude, longitude], zoom_start=5)

for i in range(0,len(c_data)):
   folium.Circle(
      location=[c_data.iloc[i]['Latitude'], c_data.iloc[i]['Longitude']],
      popup=c_data.iloc[i]['Provider'],
      radius=c_data.iloc[i]['Staff_Number']/13,
      color='Blue',
      fill=True,
      fill_color='Blue'
   ).add_to(m4)
 
    
m4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# From our maps, we can draw the following conclusions:
#    - Universities with the highest carbon emissions, student numbers, staff numbers and GIA are situated in metroplitan areas.
#    - by contrast, these variables are lower for universities in rural areas.
#    - coastal areas also record lower carbon emissions.

# %% [markdown]
# ## Section 5: Assessing whether Urbanisation affects carbon emmissions

# %% [markdown]
# #### Using the foursquare API, we will create an urbanisation metric analysing how built up an area is, based on the amount of venues within its proximity. A regression test will then be conducted to review the effect of this on carbon emmissions

# %% [markdown]
# To create this metric, we first want to record how many venues are nearby to the University

# %%
#Foursquare credentials

CLIENT_ID = '0OUHXELE02ZFO23HNGXFPEGIQB455W2Y4LZR2OC0WDEY5LBK' 
CLIENT_SECRET = 'ZDRJM1OYQGOQ0GY4JCMVBE0S1NQMJRFQD2NSH2CXBFHBIEEC' 
VERSION = '20180604'
radius = 250

# %%
#Defining the global url and reviewing request
url = 'https://api.foursquare.com/v2/venues/get?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, latitude, longitude, radius)
    
requests.get(url).json()
# Out:
# {'meta': {'code': 400,
#   'errorType': 'param_error',
#   'errorDetail': 'Value get is invalid for venue id',
#   'requestId': '5fc6b19f92d28855b9276f4b'},
#  'response': {}}

# %%
#Creating a function to explore nearby venues
def getNearbyVenues(names, latitudes, longitudes):
    venues_list =[]
    radius = 250
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, radius)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Provider', 
                  'Provider Latitude', 
                  'Provider Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
#running the function
Nearby_venues = getNearbyVenues(names = c_data['Provider'],
                                   latitudes = c_data['Latitude'],
                                   longitudes = c_data['Longitude']
                                  )
# Out:
# Anglia Ruskin University
# The Arts University Bournemouth
# Bath Spa University
# University College Birmingham
# Bournemouth University
# The University of Brighton
# Brunel University London
# Buckinghamshire New University
# Canterbury Christ Church University
# University of Northumbria at Newcastle
# City, University of London
# Conservatoire for Dance and Drama
# Coventry University
# De Montfort University
# Glasgow School of Art
# Goldsmiths College
# Imperial College of Science, Technology and Medicine
# The Institute of Cancer Research
# The University of Winchester
# King's College London
# Kingston University
# Leeds Arts University
# Leeds Beckett University
# Leeds Trinity University
# The Liverpool Institute for Performing Arts
# Liverpool Hope University
# Liverpool John Moores University
# London Metropolitan University
# London School of Economics and Political Science
# London South Bank University
# Loughborough University
# The Manchester Metropolitan University
# Middlesex University
# Norwich University of the Arts
# The Nottingham Trent University
# Oxford Brookes University
# Queen Margaret University, Edinburgh
# Queen's University Belfast
# Ravensbourne University London
# The Robert Gordon University
# Rose Bruford College of Theatre and Performance
# Royal Agricultural University
# Royal Holloway and Bedford New College
# SRUC
# Sheffield Hallam University
# Solent University
# Staffordshire University
# University for the Creative Arts
# The University of West London
# The University of Bolton
# The University of Liverpool
# University of the Highlands and Islands
# The University of Chichester
# University of Worcester
# Birmingham City University
# The University of Central Lancashire
# University of Durham
# The University of East London
# University of Gloucestershire
# The University of Greenwich
# University of Hertfordshire
# The University of Huddersfield
# The University of Hull
# The University of Kent
# The University of Lincoln
# University of Bedfordshire
# University of Nottingham
# The University of Portsmouth
# The University of Salford
# The University of Sheffield
# The University of Southampton
# The University of Sunderland
# The University of Surrey
# Teesside University
# University of the Arts, London
# The University of Warwick
# University of the West of England, Bristol
# The University of Westminster
# The University of Wolverhampton
# The University of York
# Writtle University College
# York St John University
# Aston University
# Birkbeck College
# Courtauld Institute of Art
# Glasgow Caledonian University
# Heriot-Watt University
# Keele University
# The University of Lancaster
# London Business School
# London School of Hygiene and Tropical Medicine
# Edinburgh Napier University
# The Open University
# The University of Oxford
# Queen Mary University of London
# Roehampton University
# Royal College of Art
# Royal College of Music
# The Royal Veterinary College
# SOAS University of London
# St George's, University of London
# The University of Aberdeen
# University College London
# The University of Bradford
# The University of Bristol
# The University of Cambridge
# The University of East Anglia
# The University of Edinburgh
# The University of Essex
# The University of Exeter
# University of South Wales
# The University of Glasgow
# The University of Leeds
# The University of Leicester
# University of London (Institutes and activities)
# The University of Manchester
# Newcastle University
# The University of the West of Scotland
# University of Plymouth
# The University of Reading
# The University of St Andrews
# The University of Stirling
# The University of Strathclyde
# The University of Sussex
# Ulster University
# Bishop Grosseteste University
# Cardiff University
# The Royal Central School of Speech and Drama
# Cranfield University
# Edge Hill University
# Guildhall School of Music and Drama
# Newman University
# Glyndŵr University
# Royal Academy of Music
# Royal Northern College of Music
# University of Cumbria
# St Mary's University, Twickenham
# University of Chester
# University of Abertay Dundee
# The University of Bath
# University of Derby
# The University of Dundee
# Cardiff Metropolitan University
# Swansea University
# Aberystwyth University
# Bangor University
# University of Wales Trinity Saint David
# Stranmillis University College
# Trinity Laban Conservatoire of Music and Dance
# St Mary's University College
# Falmouth University
# University of Suffolk
# University of St Mark and St John
# Harper Adams University

# %%
Nearby_venues
# Out:
#                                Provider  Provider Latitude  \
# 0              Anglia Ruskin University          51.741266
# 1              Anglia Ruskin University          51.741266
# 2              Anglia Ruskin University          51.741266
# 3              Anglia Ruskin University          51.741266
# 4              Anglia Ruskin University          51.741266
# ...                                 ...                ...
# 1652  University of St Mark and St John          50.421023
# 1653  University of St Mark and St John          50.421023
# 1654            Harper Adams University          52.780019
# 1655            Harper Adams University          52.780019
# 1656            Harper Adams University          52.780019
#
#       Provider Longitude                        Venue  Venue Latitude  \
# 0               0.474311  Best Western Atlantic Hotel       51.739884
# 1               0.474311                       Subway       51.741121
# 2               0.474311                  Papa John’s       51.741358
# 3               0.474311                         Spar       51.740872
# 4               0.474311                      Wok Inn       51.741198
# ...                  ...                          ...             ...
# 1652           -4.110286                       Barjon       50.420970
# 1653           -4.110286     UCP Marjon Sports Centre       50.419776
# 1654           -2.425380                     lamb inn       52.779259
# 1655           -2.425380        Shropshire Potato Day       52.779907
# 1656           -2.425380                The Welly Inn       52.779732
#
#       Venue Longitude      Venue Category
# 0            0.474678               Hotel
# 1            0.473110      Sandwich Place
# 2            0.473090         Pizza Place
# 3            0.473404   Convenience Store
# 4            0.473268  Chinese Restaurant
# ...               ...                 ...
# 1652        -4.110054                 Bar
# 1653        -4.113116         College Gym
# 1654        -2.427343                 Pub
# 1655        -2.425495      Farmers Market
# 1656        -2.426635                 Bar
#
# [1657 rows x 7 columns]

# %%
g_venues = Nearby_venues.groupby(by='Provider').count()
g_venues[['Venue']].hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
venues_sorted = Nearby_venues[['Provider', 'Venue']].groupby(by='Provider').count()
Provider_um = venues_sorted.rename(columns={'Venue' : 'Urbanisation_metric'})
Provider_um
# Out:
#                                             Urbanisation_metric
# Provider
# Aberystwyth University                                        1
# Anglia Ruskin University                                      6
# Aston University                                              4
# Bangor University                                             5
# Birkbeck College                                             26
# ...                                                         ...
# University of the Arts, London                               30
# University of the Highlands and Islands                       4
# University of the West of England, Bristol                    5
# Writtle University College                                    2
# York St John University                                       1
#
# [147 rows x 1 columns]

# %% [markdown]
# Now we want to add the urbanisation metric to our overall dataset

# %%
Total_data = pd.merge(c_data, Provider_um, on ="Provider")
Total_data
# Out:
#           UKPRN                                        Provider  \
# 0    10000291.0                        Anglia Ruskin University
# 1    10000385.0                 The Arts University Bournemouth
# 2    10000712.0                   University College Birmingham
# 3    10000824.0                          Bournemouth University
# 4    10000961.0                        Brunel University London
# ..          ...                                             ...
# 142  10008017.0  Trinity Laban Conservatoire of Music and Dance
# 143  10008026.0                    St Mary's University College
# 144  10014001.0                           University of Suffolk
# 145  10037449.0               University of St Mark and St John
# 146  10040812.0                         Harper Adams University
#
#      Student_Number  Staff_Number         GIA  Carbon_Emissions_Kg_CO2e  \
# 0           1763180        118000  129750.170              6.005516e+06
# 1            243940         22720   35090.950              1.133070e+06
# 2            353240         27060   67293.810              3.102714e+06
# 3           1287320         75420   91393.000              3.581960e+06
# 4           1064800         97040  246280.819              1.215999e+07
# ..              ...           ...         ...                       ...
# 142           85780         24600   18836.600              9.893457e+05
# 143           75260          6240   14585.000              4.901167e+05
# 144          553860         22200   27071.300              1.164296e+06
# 145          199600         16600   34443.000              1.689156e+06
# 146          387040         23660   57624.890              2.499884e+06
#
#      Longitude   Latitude  GIA_per_student  GIA_per_staff Labels  \
# 0     0.474311  51.741266         0.073589       1.099578      8
# 1    -1.897700  50.741781         0.143851       1.544496      5
# 2    -1.905934  52.481855         0.190505       2.486837      1
# 3    -1.897159  50.742968         0.070995       1.211787      8
# 4    -0.472835  51.532849         0.231293       2.537931      8
# ..         ...        ...              ...            ...    ...
# 142  -0.007171  51.483596         0.219592       0.765715      5
# 143  -5.961300  54.592000         0.193795       2.337340      9
# 144   1.162554  52.052585         0.048878       1.219428      5
# 145  -4.110286  50.421023         0.172560       2.074880      1
# 146  -2.425380  52.780019         0.148886       2.435541      1
#
#      Urbanisation_metric
# 0                      6
# 1                      4
# 2                     15
# 3                      4
# 4                      7
# ..                   ...
# 142                   23
# 143                    5
# 144                   14
# 145                    2
# 146                    3
#
# [147 rows x 12 columns]

# %% [markdown]
# #### testing the urbanisation metric

# %% [markdown]
# As with our other dependent variables, we will test the urbanisation metric, to analyse its effect on carbon emissions.

# %%
#Split into train and test
msk_um = np.random.rand(len(Total_data)) < 0.8
train_um = Total_data[msk_um]
test_um = Total_data[~msk_um]

# %%
#Train Data distribution
plt.scatter(train_um.Urbanisation_metric, train_um.Carbon_Emissions_Kg_CO2e, color='Brown')
plt.xlabel("Urbanisation_metric")
plt.ylabel("Carbon_Emissions_Kg_CO2e")
plt.show()

# %%
#Modelling Data
regr_um = linear_model.LinearRegression()
train_x_um = np.asanyarray(train_um[['Urbanisation_metric']])
train_y_um = np.asanyarray(train_um[["Carbon_Emissions_Kg_CO2e"]])
regr_um.fit (train_x_um, train_y_um)
print ('Coefficients: ', regr_um.coef_)
print ('Intercept: ',regr_um.intercept_)
# Out:
# Coefficients:  [[77826.97820835]]
# Intercept:  [9262559.1104154]

# %%
#Plot Outputs
plt.scatter(train_um.Urbanisation_metric, train_um.Carbon_Emissions_Kg_CO2e, color='Brown')
plt.plot(train_x_um, regr_um.coef_[0][0]*train_x_um + regr_um.intercept_[0], '-r')
plt.xlabel("Urbanisation_metric")
plt.ylabel("Carbon_Emissions_Kg_CO2e")
# Out:
# Text(0, 0.5, 'Carbon_Emissions_Kg_CO2e')

# %%
#Evaluation
test_x_um = np.asanyarray(test_um[["Carbon_Emissions_Kg_CO2e"]])
test_y_um = np.asanyarray(test_um[["Urbanisation_metric"]])
test_y_um2 = regr_um.predict(test_x_um)

print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_um2 - test_y_um)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_um2 - test_y_um) ** 2))
print("R2-score: %.2f" % r2_score(test_y_um , test_y_um2) )
# Out:
# Mean absolute error: 957972216821.94
# Residual sum of squares (MSE): 2156054157275384036458496.00
# R2-score: -22256042913810415091712.00

# %% [markdown]
# The metric is not that useful, showing no clear correlation, and when evaluated, not showing a strong result. We will however factor it into our multiple linear regression model, in order to:
#    -  assess its impact on the strength of the model
#    -  create a more informed model

# %% [markdown]
# #### Multiple Linear Regression

# %%
um_x = np.asanyarray(train_um[['Student_Number','Staff_Number','GIA', 'Urbanisation_metric']])
um_y = np.asanyarray(train_um[["Carbon_Emissions_Kg_CO2e"]])
regr_um.fit (um_x, um_y)
# The coefficients
print ('Coefficients: ', regr_um.coef_)
# Out:
# Coefficients:  [[-2.05166557e+00  4.78961925e+01  4.42431985e+01  2.50444162e+04]]

# %%
um_y_hat= regr_um.predict(test_um[['Student_Number','Staff_Number','GIA', 'Urbanisation_metric']])
um_x = np.asanyarray(test_um[['Student_Number','Staff_Number','GIA', 'Urbanisation_metric']])
um_y = np.asanyarray(test_um[["Carbon_Emissions_Kg_CO2e"]])
print("Residual sum of squares: %.2f"
      % np.mean((um_y_hat - um_y) ** 2))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr_um.score(um_x, um_y))
# Out:
# Residual sum of squares: 14216643174854.36
# Variance score: 0.93

# %% [markdown]
# This doesn't provide a better variance score than our earlier model, but the urbanisation metric doesn't lower it to much, and overall it is still a strong model, so we will use this one, as it is more informed

# %%
model=regr_um.fit(um_x,um_y)

# %% [markdown]
# ## Section 6: Using the model to predict carbon emmisions targets for a new University

# %% [markdown]
# #### Now that we have assessed our data, we can conclude that:
#    - We are best predicting carbon emmissions through our second multiple linear regression model.
#    - There are 10 benchmark clusters in our data which our prediction could fall into.
#    - The identified regional variables have to be accounted for.
#    - Urbanisation does not have a tangible effect on carbon emmisions data, based on our metric.

# %% [markdown]
# #### Testing the model

# %% [markdown]
# We want to conduct a quick test on our model, to check that it can produce the desired outcome.

# %%
Total_data.sample()
# Out:
#          UKPRN                    Provider  Student_Number  Staff_Number  \
# 96  10007783.0  The University of Aberdeen         1063920        141920
#
#            GIA  Carbon_Emissions_Kg_CO2e  Longitude   Latitude  \
# 96  265414.844              3.036758e+07  -2.099129  57.165003
#
#     GIA_per_student  GIA_per_staff Labels  Urbanisation_metric
# 96         0.249469       1.870172      9                    4

# %%
d = {'Student_Number': [1063920], 'Staff_Number': [141920], 'GIA' : [265414.844], 'Urbanisation_Metric' : 4}
df = pd.DataFrame(data=d)
print(df)
# Out:
#    Student_Number  Staff_Number         GIA  Urbanisation_Metric
# 0         1063920        141920  265414.844                    4

# %%
y_pred=model.predict(df)
print(y_pred)
# Out:
# [[15822930.29596027]]

# %% [markdown]
# #### Use Study 1 - Poppleton University

# %% [markdown]
# Our first case study is a medium sized university, situated in Leeds city centre, with a relatively large campus.

# %%
# Background and University specific data
Uni1PD = {'Student_Number': [50000], 'Staff_Number': [18000], 'GIA' : [300000], 'Urbanisation_metric' : [30]}
Uni_1 = pd.DataFrame(data=Uni1PD)
print(Uni_1)
# Out:
#    Student_Number  Staff_Number     GIA  Urbanisation_metric
# 0           50000         18000  300000                   30

# %% [markdown]
# We will now use the model to predict our estimated carbon emissions output.

# %%
# Using the model
y_pred_1=model.predict(Uni_1)
print(y_pred_1)
# Out:
# [[18020394.82815127]]

# %% [markdown]
# We want to provide the university with a ranged target for carbon emissions, so based on , we will assign a cluster, and use the minimum and maximum boundaries as a range.

# %%
# Assigning a cluster
predicted = {'Student_Number': [50000], 'Staff_Number': [5000], 'GIA' : [300000], 'Urbanisation_metric' : 30,  'Carbon_Emissions_Kg_CO2e' : y_pred_1}
p_appended = mean.append(predicted, ignore_index=True)
p_appended['Carbon_Emissions_Kg_CO2e'] = p_appended['Carbon_Emissions_Kg_CO2e'].astype('int64')
p_appended
# Out:
#            UKPRN Student_Number Staff_Number       GIA  \
# 0   1.000710e+07    2.15035e+06       323849    517671
# 1   1.000876e+07         519980      47729.6   93403.4
# 2   1.000616e+07    1.62239e+06       145501    227589
# 3   1.000780e+07          17600        43100    179130
# 4   1.000714e+07    1.04386e+06        31880    280346
# 5   1.000638e+07         297599      35010.7   42132.7
# 6   1.000777e+07    8.80978e+06       355440    131297
# 7   1.000703e+07     2.1732e+06       531853    722043
# 8   1.000552e+07    1.23699e+06       116661    182825
# 9   1.000707e+07         834256      82549.5    158538
# 10           NaN        [50000]       [5000]  [300000]
#
#     Carbon_Emissions_Kg_CO2e  Longitude   Latitude  GIA_per_student  \
# 0                   32744071  -1.996826  52.923892         0.243801
# 1                    3533777  -2.600155  52.580844         0.191151
# 2                   10908477  -2.148262  52.962709         0.148805
# 3                    7234093  -0.127819  51.520998        10.177841
# 4                   12777200  -2.642174  55.709056         0.252736
# 5                    2103157  -0.198053  51.557295         0.265189
# 6                    7127026  -0.709726  52.024924         0.014904
# 7                   54812650  -1.146526  52.734031         0.352838
# 8                    9027024  -0.190645  51.623322         0.162128
# 9                    9160558  -3.915080  55.821289         0.252520
# 10                  18020394        NaN        NaN              NaN
#
#     GIA_per_staff  Urbanisation_metric
# 0        1.605391                  NaN
# 1        2.089067                  NaN
# 2        1.594009                  NaN
# 3        4.156148                  NaN
# 4        9.491069                  NaN
# 5        1.394671                  NaN
# 6        0.369393                  NaN
# 7        1.389405                  NaN
# 8        1.635380                  NaN
# 9        2.171494                  NaN
# 10            NaN                 30.0

# %% [markdown]
# Based on the table, cluster 2 provides the closest GIA, so we'll use that one.

# %%
#create table of just that cluster
Cluster_table1 = Total_data['Labels']==2

# %%
cdf1 = pd.DataFrame(Total_data[Cluster_table1])
cdf1
# Out:
#           UKPRN                                    Provider  Student_Number  \
# 7    10001282.0      University of Northumbria at Newcastle         1904300
# 10   10001726.0                         Coventry University         2518740
# 11   10001883.0                      De Montfort University         1857160
# 20   10003861.0                    Leeds Beckett University         1675940
# 24   10003957.0            Liverpool John Moores University         1730180
# 28   10004113.0                     Loughborough University         1297760
# 29   10004180.0      The Manchester Metropolitan University         2379560
# 32   10004797.0             The Nottingham Trent University         2394340
# 41   10005790.0                 Sheffield Hallam University         2211480
# 51   10007140.0                  Birmingham City University         1861680
# 52   10007141.0        The University of Central Lancashire         1667760
# 56   10007148.0              The University of Huddersfield         1245100
# 63   10007156.0                   The University of Salford         1498500
# 66   10007159.0                The University of Sunderland         1058720
# 68   10007161.0                         Teesside University         1343980
# 71   10007164.0  University of the West of England, Bristol         2128020
# 73   10007166.0             The University of Wolverhampton         1371380
# 83   10007768.0                 The University of Lancaster         1041320
# 104  10007792.0                    The University of Exeter         1800580
# 105  10007793.0                   University of South Wales         1607600
# 108  10007796.0                 The University of Leicester         1213280
# 113  10007801.0                      University of Plymouth         1414620
# 132  10007848.0                       University of Chester         1049020
# 134  10007850.0                      The University of Bath         1300680
# 135  10007851.0                         University of Derby         1378520
# 138  10007855.0                          Swansea University         1484520
#
#      Staff_Number         GIA  Carbon_Emissions_Kg_CO2e  Longitude   Latitude  \
# 7          128840  242948.000              1.044221e+07  -1.607512  54.976769
# 10         199420  277215.860              1.310237e+07  -1.505713  52.408016
# 11         131160  180264.130              6.537805e+06  -1.139356  52.631833
# 20         129320  233337.850              7.572848e+06  -1.549143  53.803662
# 24         117780  148881.150              7.071032e+06  -2.973176  53.403702
# 28         162480  326751.360              1.967446e+07  -1.229467  52.764892
# 29         192480  272865.800              1.080362e+07  -2.239504  53.470699
# 32         178320  201310.490              1.092254e+07  -1.152002  52.956383
# 41         180440  192323.950              8.049063e+06  -1.465255  53.379212
# 51         139360  235049.112              9.348323e+06  -1.897282  52.517286
# 52         128480  181611.000              9.217372e+06  -2.707381  53.761354
# 56         102760  116717.050              6.009595e+06  -1.777712  53.643730
# 63         103320  157076.000              6.407860e+06  -2.270665  53.483558
# 66          85520  139687.930              5.014421e+06  -1.391361  54.904502
# 68          76080  155454.950              5.599936e+06  -1.234709  54.572089
# 71         176680  291629.050              1.195197e+07  -2.547491  51.500205
# 73         107480  179799.000              1.006155e+07  -2.128159  52.588308
# 83         167560  314787.000              1.500676e+07  -2.786905  54.010480
# 104        254000  279045.490              1.494074e+07  -3.534370  50.735199
# 105        111200  220412.730              7.527396e+06  -3.325787  51.588739
# 108        174440  299635.300              1.848617e+07  -1.123802  52.621937
# 113        135200  184991.600              7.441928e+06  -4.138393  50.375186
# 132         87860  197163.630              1.141886e+07  -2.898063  53.198657
# 134        160460  304920.000              1.574142e+07  -2.330671  51.380438
# 135        126520  161883.340              7.235527e+06  -1.496677  52.938545
# 138        164160  266798.680              1.517010e+07  -3.980649  51.609622
#
#      GIA_per_student  GIA_per_staff Labels  Urbanisation_metric
# 7           0.127579       1.885657      2                    6
# 10          0.110061       1.390111      2                   16
# 11          0.097064       1.374383      2                    7
# 20          0.139228       1.804345      2                   10
# 24          0.086050       1.264061      2                   26
# 28          0.251781       2.011025      2                    4
# 29          0.114671       1.417632      2                   30
# 32          0.084078       1.128928      2                   30
# 41          0.086966       1.065861      2                   30
# 51          0.126256       1.686633      2                    3
# 52          0.108895       1.413535      2                   14
# 56          0.093741       1.135822      2                   16
# 63          0.104822       1.520286      2                    2
# 66          0.131940       1.633395      2                    9
# 68          0.115668       2.043309      2                   12
# 71          0.137042       1.650606      2                    5
# 73          0.131108       1.672860      2                   13
# 83          0.302296       1.878652      2                   11
# 104         0.154975       1.098604      2                    4
# 105         0.137107       1.982129      2                    2
# 108         0.246963       1.717698      2                    7
# 113         0.130771       1.368281      2                   10
# 132         0.187950       2.244066      2                    4
# 134         0.234431       1.900287      2                    6
# 135         0.117433       1.279508      2                    4
# 138         0.179721       1.625236      2                    8

# %%
#View min/max of that cluster to get a target range
cdf1max = (cdf1.Carbon_Emissions_Kg_CO2e.max()) 
cdf1min = (cdf1.Carbon_Emissions_Kg_CO2e.min()) 
print(cdf1max)
print(cdf1min)
# Out:
# 19674461.337
# 5014421.041999999

# %% [markdown]
# We want to see where these universities in our cluster are, so that we can compare with the regional concerns of our target university

# %%
clustermap1 = folium.Map(location=[latitude, longitude], zoom_start=5)

for i in range(0,len(cdf1)):
   folium.Circle(
      location=[cdf1.iloc[i]['Latitude'], cdf1.iloc[i]['Longitude']],
      popup=cdf1.iloc[i]['Provider'],
      radius=cdf1.iloc[i]['Carbon_Emissions_Kg_CO2e']/300,
      color='crimson',
      fill=True,
      fill_color='crimson'
   ).add_to(clustermap1)
 
    
clustermap1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Based on our results we draw the following conclusions:
#  - The model predicts that the University would produce 18020394.82815127 Kg/CO2e Carbon Emissions
#  - This falls within cluster 2 of our groups - which ranges from 5014421.041999999 to 19674461.337
#  - These Universities generally are within metropolitan non-coastal areas, which is representative of our chosen case study.

# %% [markdown]
# As a result, we make the following recommendation:
#  - The predicted carbon output is in the middle of the range to aim for, and based on the likeliness to other Universities in the cluster, is a realistic target. The University should aim to record this amount of scope 1 and 2 carbon emissions at a maximum, and aim lower where possible.

# %% [markdown]
# #### Use Study 2 - The University of Life

# %% [markdown]
# We will now do the same for our second case study

# %% [markdown]
# Our second case study is a smaller specialist university, with a small campus in Cornwall.

# %%
# Background and University specific data
Uni2PD = {'Student_Number': [50000], 'Staff_Number': [7500], 'GIA' : [30000], 'Urbanisation_metric' : [1]}
Uni_2 = pd.DataFrame(data=Uni2PD)
print(Uni_2)
# Out:
#    Student_Number  Staff_Number    GIA  Urbanisation_metric
# 0           50000          7500  30000                    1

# %%
# Using the model
y_pred_2=model.predict(Uni_2)
print(y_pred_2)
# Out:
# [[1111915.94070679]]

# %%
# Assigning a cluster
predicted = {'Student_Number': [50000], 'Staff_Number': [7500], 'GIA' : [30000], 'Urbanisation_metric' : [1],  'Carbon_Emissions_Kg_CO2e' : y_pred_2}
p_appended2 = mean.append(predicted, ignore_index=True)
p_appended2['Carbon_Emissions_Kg_CO2e'] = p_appended2['Carbon_Emissions_Kg_CO2e'].astype('int64')
p_appended2
# Out:
#            UKPRN Student_Number Staff_Number      GIA  \
# 0   1.000710e+07    2.15035e+06       323849   517671
# 1   1.000876e+07         519980      47729.6  93403.4
# 2   1.000616e+07    1.62239e+06       145501   227589
# 3   1.000780e+07          17600        43100   179130
# 4   1.000714e+07    1.04386e+06        31880   280346
# 5   1.000638e+07         297599      35010.7  42132.7
# 6   1.000777e+07    8.80978e+06       355440   131297
# 7   1.000703e+07     2.1732e+06       531853   722043
# 8   1.000552e+07    1.23699e+06       116661   182825
# 9   1.000707e+07         834256      82549.5   158538
# 10           NaN        [50000]       [7500]  [30000]
#
#     Carbon_Emissions_Kg_CO2e  Longitude   Latitude  GIA_per_student  \
# 0                   32744071  -1.996826  52.923892         0.243801
# 1                    3533777  -2.600155  52.580844         0.191151
# 2                   10908477  -2.148262  52.962709         0.148805
# 3                    7234093  -0.127819  51.520998        10.177841
# 4                   12777200  -2.642174  55.709056         0.252736
# 5                    2103157  -0.198053  51.557295         0.265189
# 6                    7127026  -0.709726  52.024924         0.014904
# 7                   54812650  -1.146526  52.734031         0.352838
# 8                    9027024  -0.190645  51.623322         0.162128
# 9                    9160558  -3.915080  55.821289         0.252520
# 10                   1111915        NaN        NaN              NaN
#
#     GIA_per_staff Urbanisation_metric
# 0        1.605391                 NaN
# 1        2.089067                 NaN
# 2        1.594009                 NaN
# 3        4.156148                 NaN
# 4        9.491069                 NaN
# 5        1.394671                 NaN
# 6        0.369393                 NaN
# 7        1.389405                 NaN
# 8        1.635380                 NaN
# 9        2.171494                 NaN
# 10            NaN                 [1]

# %% [markdown]
# Based on the table, cluster 5 provides the closest mean Carbon_Emissions_Kg_CO2e, so we'll use that one.

# %%
#create table of just that cluster
Cluster_table2 = Total_data['Labels']==5

# %%
cdf2 = pd.DataFrame(Total_data[Cluster_table2])
cdf2
# Out:
#           UKPRN                                         Provider  \
# 1    10000385.0                  The Arts University Bournemouth
# 5    10000975.0                   Buckinghamshire New University
# 9    10001653.0                Conservatoire for Dance and Drama
# 13   10002718.0                               Goldsmiths College
# 15   10003324.0                 The Institute of Cancer Research
# 16   10003614.0                     The University of Winchester
# 25   10004048.0                   London Metropolitan University
# 31   10004775.0                   Norwich University of the Arts
# 36   10005389.0                   Ravensbourne University London
# 37   10005523.0  Rose Bruford College of Theatre and Performance
# 44   10006427.0                 University for the Creative Arts
# 45   10006566.0                    The University of West London
# 49   10007137.0                     The University of Chichester
# 75   10007657.0                       Writtle University College
# 78   10007760.0                                 Birkbeck College
# 79   10007761.0                       Courtauld Institute of Art
# 84   10007769.0                           London Business School
# 85   10007771.0   London School of Hygiene and Tropical Medicine
# 91   10007777.0                             Royal College of Art
# 92   10007778.0                           Royal College of Music
# 93   10007779.0                     The Royal Veterinary College
# 94   10007780.0                        SOAS University of London
# 95   10007782.0                St George's, University of London
# 120  10007811.0                    Bishop Grosseteste University
# 122  10007816.0     The Royal Central School of Speech and Drama
# 125  10007825.0              Guildhall School of Music and Drama
# 128  10007835.0                           Royal Academy of Music
# 131  10007843.0                 St Mary's University, Twickenham
# 142  10008017.0   Trinity Laban Conservatoire of Music and Dance
# 144  10014001.0                            University of Suffolk
#
#      Student_Number  Staff_Number       GIA  Carbon_Emissions_Kg_CO2e  \
# 1            243940         22720  35090.95               1133069.664
# 5            792180         28400  65873.39               2681619.953
# 9            108580         25140  53279.00               1574784.073
# 13           749400        100200  87389.00               3385380.480
# 15            18840         43500  33773.46               5178025.426
# 16           559260         49680  71007.00               2336587.102
# 25           662280         44860  92984.27               3817967.830
# 31           166000         14560  20328.00                745990.231
# 36           181980         15360  14445.00                943446.255
# 37            52960          4560  13246.00                495092.260
# 44           476280         51600  81982.00               3331343.941
# 45           796060         60760  50298.00               2455591.672
# 49           393560         36760  82504.13               2358924.987
# 75            53900         12300  40351.00               1243067.053
# 78           819880         81040  40491.85               1985649.671
# 79            35640          6040  13485.00                456340.662
# 84           149400         32960  40541.63               2611689.613
# 85            84380         68340  27429.00               1804899.263
# 91           172840         29560  34410.31               2158235.000
# 92            59280         19960  12261.60                563660.903
# 93           181580         39880  50752.00               4450992.842
# 94           417520         53340  48087.44               1359860.852
# 95           337440         41240  70542.08               7656865.655
# 120          162560         16560  22386.85                897127.757
# 122           75860         16800  13669.00                494846.883
# 125           78220         35800  33817.04               1696165.294
# 128           63400         19640  14504.35                689178.005
# 131          395100         31960  53143.00               2434694.747
# 142           85780         24600  18836.60                989345.674
# 144          553860         22200  27071.30               1164296.062
#
#      Longitude   Latitude  GIA_per_student  GIA_per_staff Labels  \
# 1    -1.897700  50.741781         0.143851       1.544496      5
# 5    -0.752021  51.627518         0.083155       2.319486      5
# 9    -0.129090  51.526207         0.490689       2.119292      5
# 13   -0.035375  51.474144         0.116612       0.872146      5
# 15   -0.181668  51.490713         1.792646       0.776401      5
# 16   -1.326928  51.060033         0.126966       1.429287      5
# 25   -0.110210  51.551822         0.140400       2.072766      5
# 31    1.296600  52.630313         0.122458       1.396154      5
# 36    0.005266  51.501478         0.079377       0.940430      5
# 37    0.106805  51.439004         0.250113       2.904825      5
# 44   -0.805496  51.215767         0.172130       1.588798      5
# 45   -0.303390  51.506610         0.063184       0.827814      5
# 49   -0.774409  50.844268         0.209635       2.244400      5
# 75    0.428134  51.737004         0.748627       3.280569      5
# 78   -0.127819  51.520998         0.049388       0.499653      5
# 79   -0.116912  51.510734         0.378367       2.232616      5
# 84   -0.161353  51.526583         0.271363       1.230025      5
# 85   -0.130661  51.520927         0.325065       0.401361      5
# 91   -0.178449  51.501355         0.199088       1.164084      5
# 92   -0.176889  51.499281         0.206842       0.614309      5
# 93   -0.133498  51.536862         0.279502       1.272618      5
# 94   -0.129233  51.522352         0.115174       0.901527      5
# 95   -0.173355  51.427985         0.209051       1.710526      5
# 120  -0.535716  53.244036         0.137714       1.351863      5
# 122  -0.174179  51.544337         0.180187       0.813631      5
# 125  -0.092406  51.519502         0.432332       0.944610      5
# 128  -0.151727  51.523617         0.228775       0.738511      5
# 131  -0.335292  51.437438         0.134505       1.662797      5
# 142  -0.007171  51.483596         0.219592       0.765715      5
# 144   1.162554  52.052585         0.048878       1.219428      5
#
#      Urbanisation_metric
# 1                      4
# 5                     17
# 9                     26
# 13                    22
# 15                     7
# 16                     5
# 25                    18
# 31                    30
# 36                    30
# 37                     2
# 44                     1
# 45                    13
# 49                     2
# 75                     2
# 78                    26
# 79                    24
# 84                    14
# 85                    30
# 91                    18
# 92                    28
# 93                     4
# 94                    26
# 95                     6
# 120                    2
# 122                   28
# 125                   30
# 128                   10
# 131                    1
# 142                   23
# 144                   14

# %%
#View min/max of that cluster to get a target range
cdf2max = (cdf2.Carbon_Emissions_Kg_CO2e.max()) 
cdf2min = (cdf2.Carbon_Emissions_Kg_CO2e.min()) 
print(cdf2max)
print(cdf2min)
# Out:
# 7656865.655
# 456340.662

# %%
clustermap2 = folium.Map(location=[latitude, longitude], zoom_start=5)

for i in range(0,len(cdf2)):
   folium.Circle(
      location=[cdf2.iloc[i]['Latitude'], cdf2.iloc[i]['Longitude']],
      popup=cdf2.iloc[i]['Provider'],
      radius=cdf2.iloc[i]['Carbon_Emissions_Kg_CO2e']/300,
      color='crimson',
      fill=True,
      fill_color='crimson'
   ).add_to(clustermap2)
 
    
clustermap2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Based on our results we draw the following conclusions:
#  - The model predicts that the University would produce 1111915.94070679 Kg/CO2e Carbon Emissions
#  - This falls within cluster 5 of our groups - which ranges from 456340.662 to 7656865.655
#  - These Universities vary between metropolitan non-coastal areas, and more rural areas some of which are coastal.

# %% [markdown]
# As a result, we make the following recommendation:
#  - The predicted carbon output is at the lower end of the range to aim for, and based on the likeliness to other Universities in the cluster, and the case studies position as a rural, coastal campus, this is a realistic target. The University should aim to record this amount of scope 1 and 2 carbon emissions at a maximum, and aim lower where possible.
